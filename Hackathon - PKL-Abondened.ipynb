# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
players=pd.read_excel("D:/Dropbox/PGP - Data Science/Jupyter Notebooks/Hackathon - PKL/player_details.xlsx")
players.head()
# Out:
#    match_id Team  id             name       short_name  skill  role  red_card  \
# 0         1  JAI  15  Sanjay Shrestha  Sanjay Shrestha    NaN   NaN     False
# 1         1  JAI  96       Rohit Rana       Rohit Rana    NaN   NaN     False
# 2         1  JAI  72   Navneet Gautam   Navneet Gautam    NaN   NaN     False
# 3         1  JAI  52     Jasvir Singh     Jasvir Singh    NaN   NaN     False
# 4         1  JAI  22         Wei Yang         Wei Yang    NaN   NaN     False
#
#    yellow_card  green_card  ...  raids_successful  raids_unsuccessful  \
# 0        False       False  ...                 0                   0
# 1        False       False  ...                 0                   0
# 2        False       False  ...                 0                   0
# 3        False       False  ...                 7                   3
# 4        False       False  ...                 0                   0
#
#    raids_Empty  raids_total.1  raids_successful.1  raids_unsuccessful.1  \
# ...

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17489 entries, 0 to 17488
# Data columns (total 35 columns):
# match_id                       17489 non-null int64
# Team                           17489 non-null object
# id                             17489 non-null int64
# name                           17489 non-null object
# short_name                     1698 non-null object
# skill                          0 non-null float64
# role                           0 non-null float64
# red_card                       17489 non-null bool
# yellow_card                    17489 non-null bool
# green_card                     17489 non-null bool
# jersey                         17489 non-null int64
# played                         17489 non-null bool
# captain                        17489 non-null bool
# on_court                       17489 non-null bool
# starter                        17489 non-null bool
# top_raider                     17489 non-null bool
# ...

# %%
players=players.drop(['skill','role','short_name','id','match_id','jersey'], axis=1)
players.head()
# Out:
#   Team             name  red_card  yellow_card  green_card  played  captain  \
# 0  JAI  Sanjay Shrestha     False        False       False    True    False
# 1  JAI       Rohit Rana     False        False       False    True    False
# 2  JAI   Navneet Gautam     False        False       False    True     True
# 3  JAI     Jasvir Singh     False        False       False    True    False
# 4  JAI         Wei Yang     False        False       False    True    False
#
#    on_court  starter  top_raider  ...  raids_successful  raids_unsuccessful  \
# 0      True     True       False  ...                 0                   0
# 1      True     True       False  ...                 0                   0
# 2      True     True       False  ...                 0                   0
# 3     False     True       False  ...                 7                   3
# 4      True     True       False  ...                 0                   0
#
# ...

# %%
players.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17489 entries, 0 to 17488
# Data columns (total 29 columns):
# Team                           17489 non-null object
# name                           17489 non-null object
# red_card                       17489 non-null bool
# yellow_card                    17489 non-null bool
# green_card                     17489 non-null bool
# played                         17489 non-null bool
# captain                        17489 non-null bool
# on_court                       17489 non-null bool
# starter                        17489 non-null bool
# top_raider                     17489 non-null bool
# top_defender                   17489 non-null bool
# Player_points_total            17489 non-null int64
# raider_points_total            17489 non-null int64
# raider_points_touch            17489 non-null int64
# raider_points_raid_bonus       17489 non-null int64
# tackle_points_total            17489 non-null int64
# ...

# %%
players
# Out:
#       Team              name  red_card  yellow_card  green_card  played  \
# 0      JAI   Sanjay Shrestha     False        False       False    True
# 1      JAI        Rohit Rana     False        False       False    True
# 2      JAI    Navneet Gautam     False        False       False    True
# 3      JAI      Jasvir Singh     False        False       False    True
# 4      JAI          Wei Yang     False        False       False    True
# ...    ...               ...       ...          ...         ...     ...
# 17484   TT          Himanshu     False        False       False    True
# 17485   TT  Yashwant Bishnoi     False        False       False    True
# 17486   TT     Victor Obiero     False        False       False   False
# 17487   TT             Sagar     False        False       False    True
# 17488   TT     Vineet Sharma     False        False       False    True
#
#        captain  on_court  starter  top_raider  ...  raids_successful  \
# ...

# %%
# Creating a list of the columns for Univariate Analysis

uni_cols=list(players.columns)
#uni_cols_to_remove=['Garage_Age','Property_Age','SalePrice','ScreenPorch','EnclosedPorch','OpenPorchSF','WoodDeckSF',
#                    'GarageArea','GrLivArea','2ndFlrSF','1stFlrSF','TotalBsmtSF','BsmtUnfSF','BsmtFinSF2','BsmtFinSF1',
#                    'YearRemodAdd','LotArea','LotFrontage']

#for each in uni_cols_to_remove:
#    uni_cols.remove(each)

# Defining the function for plotting graphs for Univariate Analysis
def univariate_dist(colname,m=12,n=8):
    plt.figure(num=None,figsize=(m,n),dpi=60,facecolor='w',edgecolor='k')
    ax=sns.countplot(colname,data=players,order = players[colname].value_counts().index)
    plt.title(f'Distribution of {colname}.')
    plt.xticks(rotation=90)
    plt.grid()
    
    for p in ax.patches:
        x=p.get_bbox().get_points()[:,0]
        y=p.get_bbox().get_points()[1,1]
        ax.annotate('{:.2f}%'.format(100.*y/len(players)), (x.mean(), y), 
                    ha='center', va='bottom',color='black',weight='bold') # set the alignment of the text
        
# Calling Univariate function for each column

for each in uni_cols:
    univariate_dist(each)
# Out:
# C:\Users\Bhojraj Rohilla\AppData\Roaming\Python\Python37\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
names=['Sandeep','Pawan']

players['name'].unique()
# Out:
# array(['Sanjay Shrestha', 'Rohit Rana', 'Navneet Gautam', 'Jasvir Singh',
#        'Wei Yang', 'Gokul Shitole', 'Prashant Chavan', 'Balbir Singh',
#        'Gangadhari Mallesh', 'Raju Lal Choudhary', 'Rajesh Narwal',
#        'Maninder Singh', 'Jeeva Kumar', 'Jeeva Gopal', 'Surender Nada',
#        'Masayuki Shimokawa', 'Shabeer Bappu', 'Mohammad Ziaur Rahman',
#        'Suresh Pathapalem', 'Vishal Mane', 'Rishank Devadiga',
#        'Mohit Chhillar', 'Anup Kumar', 'Md. Aruduzzaman Munshi',
#        'I Ketut Ariana', 'Rajesh Mondal', 'Parmod Narwal',
#        'Gurpreet Singh', 'Dharmaraj Cheralathan', 'Sarun Das',
#        'Manjeet Chhillar', 'Ajay Thakur', 'Sunil Hanumanthappa',
#        'Vilam Singh', 'Kiran Parmar', 'Sinotharan Kanesharajah',
#        'Michael Adam Dubery', 'Haresh Jalmi', 'Punit Kumar Teotia',
#        'Takamitsu Kono', 'Amit Singh Chhillar', 'Dadaso Balaso Awad',
#        'Ehsan Zamani Fard', 'Dong Ju Hong', 'Surjeet Narwal',
# ...
